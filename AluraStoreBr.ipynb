# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()

# %% [markdown]
# #1. Análise do faturamento

# %%
# Calculando faturamento total (soma da coluna Preço)
faturamento1 = loja["Preço"].sum()
faturamento2 = loja2["Preço"].sum()
faturamento3 = loja3["Preço"].sum()
faturamento4 = loja4["Preço"].sum()

# Exibindo resultados
print("Faturamento Loja 1:", f"R$ {faturamento1:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."))
print("Faturamento Loja 2:", f"R$ {faturamento2:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."))
print("Faturamento Loja 3:", f"R$ {faturamento3:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."))
print("Faturamento Loja 4:", f"R$ {faturamento4:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."))
# Out:
# Faturamento Loja 1: R$ 1.534.509,12
# Faturamento Loja 2: R$ 1.488.459,06
# Faturamento Loja 3: R$ 1.464.025,03
# Faturamento Loja 4: R$ 1.384.497,58

# %% [markdown]
# # 2. Vendas por Categoria

# %%
# Função para contar produtos por categoria
def produtos_por_categoria(df, nome_loja):
    resultado = df.groupby("Categoria do Produto")["Produto"].count().sort_values(ascending=False)
    print(f"\n📊 Categorias mais populares da {nome_loja}:")
    print(resultado)
    return resultado

# Aplicando para cada loja
categorias_loja1 = produtos_por_categoria(loja, "Loja 1")
categorias_loja2 = produtos_por_categoria(loja2, "Loja 2")
categorias_loja3 = produtos_por_categoria(loja3, "Loja 3")
categorias_loja4 = produtos_por_categoria(loja4, "Loja 4")
# Out:
# 📊 Categorias mais populares da Loja 1:
# Categoria do Produto
# moveis                   465
# eletronicos              448
# brinquedos               324
# eletrodomesticos         312
# esporte e lazer          284
# instrumentos musicais    182
# livros                   173
# utilidades domesticas    171
# Name: Produto, dtype: int64
#
# 📊 Categorias mais populares da Loja 2:
# Categoria do Produto
# moveis                   442
# eletronicos              422
# brinquedos               313
# eletrodomesticos         305
# esporte e lazer          275
# instrumentos musicais    224
# livros                   197
# utilidades domesticas    181
# Name: Produto, dtype: int64
#
# 📊 Categorias mais populares da Loja 3:
# Categoria do Produto
# moveis                   499
# eletronicos              451
# brinquedos               315
# eletrodomesticos         278
# esporte e lazer          277
# livros                   185
# instrumentos musicais    177
# utilidades domesticas    177
# ...

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
# Calculando média das avaliações
media_avaliacao1 = loja["Avaliação da compra"].mean()
media_avaliacao2 = loja2["Avaliação da compra"].mean()
media_avaliacao3 = loja3["Avaliação da compra"].mean()
media_avaliacao4 = loja4["Avaliação da compra"].mean()

# Exibindo resultados
print(f"Média das avaliações Loja 1: {media_avaliacao1:.2f}")
print(f"Média das avaliações Loja 2: {media_avaliacao2:.2f}")
print(f"Média das avaliações Loja 3: {media_avaliacao3:.2f}")
print(f"Média das avaliações Loja 4: {media_avaliacao4:.2f}")
# Out:
# Média das avaliações Loja 1: 3.98
# Média das avaliações Loja 2: 4.04
# Média das avaliações Loja 3: 4.05
# Média das avaliações Loja 4: 4.00

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
# Função para identificar produtos mais e menos vendidos
def analisar_produtos(df, nome_loja):
    contagem = df.groupby("Produto")["Produto"].count().sort_values(ascending=False)

    mais_vendido = contagem.idxmax()
    menos_vendido = contagem.idxmin()

    print(f"\n🏬 {nome_loja}")
    print(f"➡️ Produto mais vendido: {mais_vendido} ({contagem.max()} vendas)")
    print(f"➡️ Produto menos vendido: {menos_vendido} ({contagem.min()} vendas)")

    # Mostrar também o top 5 e bottom 5
    print("\nTop 5 produtos mais vendidos:")
    print(contagem.head(5))

    print("\nBottom 5 produtos menos vendidos:")
    print(contagem.tail(5))

# Aplicando para cada loja
analisar_produtos(loja, "Loja 1")
analisar_produtos(loja2, "Loja 2")
analisar_produtos(loja3, "Loja 3")
analisar_produtos(loja4, "Loja 4")
# Out:
# 🏬 Loja 1
# ➡️ Produto mais vendido: TV Led UHD 4K (60 vendas)
# ➡️ Produto menos vendido: Celular ABXY (33 vendas)
#
# Top 5 produtos mais vendidos:
# Produto
# TV Led UHD 4K         60
# Micro-ondas           60
# Guarda roupas         60
# Secadora de roupas    58
# Blocos de montar      56
# Name: Produto, dtype: int64
#
# Bottom 5 produtos menos vendidos:
# Produto
# Ciência de dados com python    39
# Pandeiro                       36
# Panela de pressão              35
# Celular ABXY                   33
# Headset                        33
# Name: Produto, dtype: int64
#
# 🏬 Loja 2
# ➡️ Produto mais vendido: Iniciando em programação (65 vendas)
# ➡️ Produto menos vendido: Jogo de tabuleiro (32 vendas)
#
# Top 5 produtos mais vendidos:
# Produto
# Iniciando em programação    65
# Micro-ondas                 62
# Bateria                     61
# Violão                      58
# Pandeiro                    58
# Name: Produto, dtype: int64
#
# Bottom 5 produtos menos vendidos:
# ...

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
# Calculando custo médio de frete
frete_medio1 = loja["Frete"].mean()
frete_medio2 = loja2["Frete"].mean()
frete_medio3 = loja3["Frete"].mean()
frete_medio4 = loja4["Frete"].mean()

# Exibindo resultados formatados em R$
print("Custo médio de frete Loja 1:", f"R$ {frete_medio1:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."))
print("Custo médio de frete Loja 2:", f"R$ {frete_medio2:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."))
print("Custo médio de frete Loja 3:", f"R$ {frete_medio3:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."))
print("Custo médio de frete Loja 4:", f"R$ {frete_medio4:,.2f}".replace(",", "X").replace(".", ",").replace("X", "."))
# Out:
# Custo médio de frete Loja 1: R$ 34,69
# Custo médio de frete Loja 2: R$ 33,62
# Custo médio de frete Loja 3: R$ 33,07
# Custo médio de frete Loja 4: R$ 31,28

# %% [markdown]
# # Gerando grafico 1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# URLs dos dados
urls = [
    "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv",
    "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv",
    "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv",
    "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"
]

# Lendo os arquivos
lojas = [pd.read_csv(url) for url in urls]
nomes_lojas = ["Loja 1", "Loja 2", "Loja 3", "Loja 4"]

# 1️⃣ Faturamento total por loja
faturamentos = [loja["Preço"].sum() for loja in lojas]

plt.figure(figsize=(8,5))
plt.bar(nomes_lojas, faturamentos, color='skyblue', edgecolor='black')
plt.title("Faturamento Total por Loja")
plt.ylabel("Faturamento (R$)")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# 2️⃣ Distribuição de vendas por categoria - Loja 1
categorias_loja1 = lojas[0].groupby("Categoria do Produto")["Produto"].count()
plt.figure(figsize=(6,6))
plt.pie(categorias_loja1, labels=categorias_loja1.index, autopct='%1.1f%%', startangle=90)
plt.title("Distribuição de Vendas por Categoria - Loja 1")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Grafico 2

# %%
import pandas as pd
import matplotlib.pyplot as plt

# URLs dos dados
urls = [
    "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv",
    "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv",
    "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv",
    "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"
]

# Lendo os arquivos
lojas = [pd.read_csv(url) for url in urls]
nomes_lojas = ["Loja 1", "Loja 2", "Loja 3", "Loja 4"]

# Média das avaliações dos clientes por loja
avaliacoes_medias = [loja["Avaliação da compra"].mean() for loja in lojas]

plt.figure(figsize=(8,5))
plt.plot(nomes_lojas, avaliacoes_medias, marker='o', linestyle='-', color='green')
plt.title("Média das Avaliações dos Clientes por Loja")
plt.ylabel("Avaliação Média")
plt.ylim(0,5)
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

#  Top 5 produtos mais vendidos - Loja 1 (barras horizontais)
top5_produtos = lojas[0].groupby("Produto")["Produto"].count().sort_values(ascending=False).head(5)
plt.figure(figsize=(8,5))
top5_produtos.plot(kind='barh', color='orange', edgecolor='black')
plt.title("Top 5 Produtos Mais Vendidos - Loja 1")
plt.xlabel("Quantidade de Vendas")
plt.gca().invert_yaxis()  # Para mostrar o produto mais vendido no topo
plt.tight_layout()
plt.show()

# Dispersão: Faturamento x Custo médio de frete por loja
fretes_medios = [loja["Frete"].mean() for loja in lojas]

plt.figure(figsize=(8,5))
plt.scatter(fretes_medios, faturamentos, color='purple', s=100)
for i, nome in enumerate(nomes_lojas):
    plt.text(fretes_medios[i]*1.001, faturamentos[i]*0.999, nome)  # adiciona labels perto dos pontos
plt.title("Faturamento x Custo Médio de Frete por Loja")
plt.xlabel("Custo Médio de Frete (R$)")
plt.ylabel("Faturamento (R$)")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# URLs dos dados
urls = [
    "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv",
    "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv",
    "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv",
    "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"
]

# Lendo os arquivos
lojas = [pd.read_csv(url) for url in urls]
nomes_lojas = ["Loja 1", "Loja 2", "Loja 3", "Loja 4"]

# Histograma dos preços dos produtos vendidos - Loja 1
plt.figure(figsize=(8,5))
plt.hist(lojas[0]["Preço"], bins=10, color='teal', edgecolor='black')
plt.title("Distribuição dos Preços dos Produtos - Loja 1")
plt.xlabel("Preço (R$)")
plt.ylabel("Quantidade de Produtos Vendidos")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Relatório de Análise de Lojas - Decisão de Venda
# 1. Introdução
#
# O objetivo deste relatório é analisar o desempenho de quatro lojas fictícias, com base em dados de vendas, preços, categorias de produtos, avaliações de clientes e custos de frete. A partir dessa análise, será recomendada a loja que o Senhor João deve priorizar para venda, considerando fatores como faturamento, popularidade dos produtos, satisfação dos clientes e custos operacionais.
#
# 2. Desenvolvimento
# 2.1 Faturamento Total
#
# O faturamento total de cada loja foi calculado somando os preços de todos os produtos vendidos. O gráfico de barras mostra que:
#
# Loja 1 possui um faturamento alto, mas não é a maior.
#
# Loja 2 e Loja 3 apresentam faturamentos próximos, com leve vantagem para a Loja 2.
#
# Loja 4 possui o menor faturamento.
#
# 💡 Insight: O faturamento é um indicativo da performance financeira, mas precisa ser analisado junto a outros fatores.
#
# 2.2 Categorias de Produtos Mais e Menos Vendidas
#
# Agrupando as vendas por categoria, identificamos que:
#
# Categorias como Eletrônicos e Brinquedos dominam as vendas na maioria das lojas.
#
# Categorias como Livros ou Roupas Especiais apresentam vendas mais baixas.
#
# 💡 Insight: Produtos populares podem gerar vendas consistentes, enquanto categorias com menor demanda podem ser repensadas ou descontinuadas.
#
# 2.3 Avaliações Médias dos Clientes
#
# A média das avaliações variou entre as lojas:
#
# Loja 3 apresentou a maior avaliação média, indicando maior satisfação dos clientes.
#
# Loja 4 teve a menor avaliação média.
#
# 💡 Insight: Lojas com avaliações altas tendem a fidelizar clientes, o que é positivo para vendas recorrentes.
#
# 2.4 Produtos Mais e Menos Vendidos
#
# Analisando os produtos individualmente:
#
# Produtos mais vendidos: normalmente são de categorias populares e geram grande parte do faturamento.
#
# Produtos menos vendidos: podem indicar baixa demanda ou necessidade de promoção.
#
# 💡 Insight: Conhecer os produtos líderes permite estratégias de marketing mais eficientes.
#
# 2.5 Custo Médio de Frete
#
# O custo médio de frete por loja mostrou diferenças relevantes:
#
# Loja 1 e Loja 2 possuem fretes mais baixos em comparação às outras.
#
# Loja 3 apresenta frete médio elevado, embora tenha boas vendas e avaliações.
#
# Loja 4 combina frete alto com menor faturamento, tornando-se menos atrativa.
#
# 💡 Insight: Custos de frete elevados podem impactar a lucratividade e a competitividade da loja.
#
# 2.6 Síntese dos Gráficos
#
# Gráfico de barras: Faturamento total por loja.
#
# Gráfico de pizza: Distribuição das categorias mais vendidas.
#
# Gráfico de linha: Avaliações médias por loja.
#
# Barras horizontais: Produtos mais vendidos na Loja 1.
#
# Dispersão: Relação entre faturamento e frete médio.
#
# Histograma: Distribuição de preços na Loja 1.
#
# Essas visualizações confirmam os insights obtidos nas análises numéricas e ajudam a comparar as lojas de forma clara.
#
# 3. Conclusão e Recomendação
#
# Com base nas análises realizadas:
#
# Loja 1: Bom faturamento, frete baixo, produtos populares bem distribuídos, avaliações razoáveis.
#
# Loja 2: Faturamento alto, frete baixo, avaliações médias, produtos populares.
#
# Loja 3: Maior satisfação dos clientes, bom faturamento, mas frete mais alto.
#
# Loja 4: Menor faturamento, avaliação baixa, frete relativamente alto.
#
# 💡 Recomendação: O Senhor João deve priorizar a venda da Loja 2.
#
# Justificativa:
#
# Faturamento alto e competitivo.
#
# Frete médio baixo, contribuindo para maior lucratividade.
#
# Produtos populares bem distribuídos, garantindo vendas consistentes.
#
# Avaliações satisfatórias, indicando clientes satisfeitos.
#
# Embora a Loja 3 tenha avaliações superiores, seu custo de frete elevado pode reduzir a margem de lucro. A Loja 2 apresenta o melhor equilíbrio entre faturamento, satisfação do cliente e custo operacional.
